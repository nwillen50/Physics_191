# %%
from graphs import env_graph, osc_graph, ft_graph

# %%
file = 'Data/FT/MRI/HShort_y.csv'
ft_graph(file)
# Out:
# /Users/nicholaswillen/Documents/Coding/Harvard Classes/Physics 191/NMR/graphs.py:120: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# (array([0.000000e+00, 2.500000e+02, 5.000000e+02, ..., 1.249950e+07,
#         1.249975e+07, 1.250000e+07], shape=(50001,)),
#  array([2.62255136e-03, 2.57901192e-03, 2.09632104e-03, ...,
#         4.64419079e-06, 1.67560095e-06, 3.92333100e-06], shape=(50001,)),
#  array([ 97, 105]))
